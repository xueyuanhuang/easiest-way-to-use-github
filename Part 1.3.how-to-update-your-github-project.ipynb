# %% [markdown]
# 1.before my github project look like this...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.in git bash type in "git push"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.refresh your website...

# %% [markdown]
# ![image.png](attachment:image.png)
