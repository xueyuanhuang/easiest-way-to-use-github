# %% [markdown]
# 1.open .gitignore

# %% [markdown]
# 2.type in
#
# 2.1.<\**/.ipynb_checkpoints>
#
# 2.2.<.ipynb_checkpoints/>
#
# ---
# 2.1. is to ignore all child directories' <.ipynb_checkpoints>
#
# 2.2. is to ignore root directory's <.ipynb_checkpoints> end with forward slash(/) specific this is for directory only

# %% [markdown]
# ![image.png](attachment:image.png)
