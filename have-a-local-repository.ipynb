# %% [markdown]
# 1.[open bash git](open-git-bash.ipynb), type in 'git init'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.[ignore files in the repository that you don't want git to manage](ignoring-files.ipynb)

# %% [markdown]
# 3.'git add .'
#
# here just add everything into git, but you could choose file to add

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.'git commit -m "first commit message"'

# %% [markdown]
# ![image.png](attachment:image.png)
