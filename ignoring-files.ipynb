# %% [markdown]
# # 1.workflow of ignoring files

# %% [markdown]
# Here I use ignore a directory as an example, actually you can ignore everything file, files, directory, directories...

# %% [markdown]
# 1.creat a file named .gitignore in your root directory

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.in .gitignore write files you want to ignore, save it

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.add .gitignore into git

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4."git status" you can see that .ipynb_checkpoints is't inside

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.examples of ignoring

# %% [markdown]
# ## [2.1. specific directories' name in root and child directories ](ignore-specific-directories-name.ipynb)
