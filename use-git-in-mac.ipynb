# %% [markdown]
# # init
# 1.cmd+space, type in terminal
# 2.git --version(need to install command line develop tool)
# 3.
# git config --global user.name "Emma Paris"
# git config --global user.email "eparis@atlassian.com"

# %% [markdown]
# # open terminal in specific path

# %% [markdown]
# 1.use finder, go to specific path
# 2.option+cmd+p, to show path
# 3.ctrl+click the fold name, choose `open in terminal`

# %% [markdown]
# ![image.png](attachment:eb46841d-0b8e-4a3f-887a-0de63cd22ee8.png)

# %% [markdown]
# 4.check if right path, see terminal top
# ![image.png](attachment:c7aaf4f3-c55f-4aab-8427-eb6a19936ded.png)

# %% [markdown]
# # git push

# %% [markdown]
# 1.go to github.com, click setting
# ![image.png](attachment:60731582-b8be-403a-b8c3-87feb92ea82a.png)

# %% [markdown]
# 2.go to the bottom, to find 'developer setting', click it
# ![image.png](attachment:3b6f39d3-14e3-4ee4-a081-633a4acb3228.png)

# %% [markdown]
# 3.choose `personal access token`, choose `Tokens(classic)`.
# ![image.png](attachment:3f95e3eb-3031-4a4e-a0e2-3c6d78378bf1.png)

# %% [markdown]
# 4.choose to generate new token, choose classic one
# ![image.png](attachment:206b3d14-f2e4-4562-96db-7a23e79b9464.png)

# %% [markdown]
# 5.just click all, and go to bottom to click green button`gerenate token`
# 6.save it, and next time you use `git push`, enter your username, for passwords enter `the token you just get`

# %% [markdown]
# # use .gitignore

# %% [markdown]
# 1.open terminal
# 2.type in `nano .gitignore`
