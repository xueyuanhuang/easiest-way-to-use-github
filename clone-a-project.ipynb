# %% [markdown]
# 1.trying to find a project in "github.com", you are interested in

# %% [markdown]
# 2.you should get down to the page looks like ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.as above shown, there is a button "code", click it...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.copy the link above picture

# %% [markdown]
# 5.find somewhere in your local computer, for example

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6.click the right side of your mouse, there should be a option called "open git bash here"
#
# if not, click here(should be a link here tell you how to downlaod git)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7.in git bash type in 'git clone https://github.com/xueyuanhuang/easiest-way-to-use-github.git'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 8.now you should have a project looks like below:

# %% [markdown]
# ![image.png](attachment:image.png)
