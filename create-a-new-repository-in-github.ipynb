# %% [markdown]
# 1.login to your account
#
# or you don't have one, please create

# %% [markdown]
# 2.create a new repository in github

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.click 'new repository'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.fill out only two box, you can see above...

# %% [markdown]
# 5.you should be able to find your **new repository's url** in the jump out page,see below...

# %% [markdown]
# ![image.png](attachment:image.png)
