# %% [markdown]
# 1.[create your new repository](create-a-new-repository-in-github.ipynb) in your account

# %% [markdown]
# 2.after you create your new repository, it should automatically jump into below page

# %% [markdown]
# ![image.png](attachment:8169364e-2672-4677-b0bb-b10f6df6fe50.png)

# %% [markdown]
# 3.For me I choose above red rectangular but alter a bit
# git init
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/xueyuanhuang/qf602.git
# git push -u origin main

# %% [markdown]
# 4.if this your first time to do this, you probably need to genarate to [personal access key](use-git-in-mac.ipynb)
# see "git push" part after jump into

# %% [markdown]
# ![image.png](attachment:30921b33-6ad8-4ba7-9497-73ead55c0efd.png)

# %% [markdown]
# 5.congrats! you check on github, it should be there
