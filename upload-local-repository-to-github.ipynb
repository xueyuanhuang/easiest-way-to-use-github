# %% [markdown]
# 1.you need to [have a local repository first](have-a-local-repository.ipynb)

# %% [markdown]
# 2.[create your new repository](create-a-new-repository-in-github.ipynb) in your account

# %% [markdown]
# 3.in git bash, type in 'git remote add origin <your new repository's url>'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.'git push --set-upstream origin master'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5.check on github, refresh the page, you should see below...

# %% [markdown]
# ![image.png](attachment:image.png)
