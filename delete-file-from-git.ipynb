# %% [markdown]
# 1.'git rm --cache \<filename>'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.'git commit -m "delete a file"'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.attention: if you have argument <--cache> it will delete from git but not from your working directory

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.I highly recommend use this argument
#
# in case some day you delete .git, but other day you want this file, then you will never found it
