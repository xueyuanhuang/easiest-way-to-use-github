# %% [markdown]
# ![image.png](attachment:d978d566-83ea-4686-9b73-5a215c10a741.png)

# %% [markdown]
# acutually you need to use `git rm --cached session1`
# not `rm -rf session1/.git` as it just let the repo dispear
