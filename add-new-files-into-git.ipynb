# %% [markdown]
# 1.in git bash, type in "git status"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2."git add clone-a-project.ipynb"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.'git commit -m "add a new file"'

# %% [markdown]
# ![image.png](attachment:image.png)
