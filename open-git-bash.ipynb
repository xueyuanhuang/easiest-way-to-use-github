# %% [markdown]
# 1.frist thing first:you need to know where you want to open a git bash,below is an example...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.click right part of your mouse, should be have below icon...
#
# if there is not, then you should download a git(link)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3.click "open git bash here"

# %% [markdown]
# 4.you will open git bash in exact place you want, see below...

# %% [markdown]
# ![image.png](attachment:image.png)
